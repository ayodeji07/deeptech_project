# %%
import geopandas as gpd
import rasterio
import ee  # For GEE

# %%
import ee

# Initialize with your project
ee.Initialize(project='ee-nigeria-disease-project')  # Your exact Project ID

print("Initialization successful! Project is registered.")

# Test with a valid Landsat 8 Collection 2 TOA image
image = ee.Image('LANDSAT/LC08/C02/T1_TOA/LC08_044034_20140926')

# Fetch and print basic info
info = image.getInfo()
print(f"Sample image loaded successfully!")
print(f"Image type: {info['type']}")
print(f"Image ID: {info['id']}")  # Top-level 'id' key
print(f"Landsat Product ID: {info['properties'].get('LANDSAT_PRODUCT_ID', 'N/A')}")  # From properties
print(f"Band names: {[band['id'] for band in info['bands']]}")  # Extract from list of band dicts
print("Test passed—GEE is fully operational for your project!")
# Out:
# Initialization successful! Project is registered.
# Sample image loaded successfully!
# Image type: Image
# Image ID: LANDSAT/LC08/C02/T1_TOA/LC08_044034_20140926
# Landsat Product ID: LC08_L1TP_044034_20140926_20200910_02_T1
# Band names: ['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B9', 'B10', 'B11', 'QA_PIXEL', 'QA_RADSAT', 'SAA', 'SZA', 'VAA', 'VZA']
# Test passed—GEE is fully operational for your project!
